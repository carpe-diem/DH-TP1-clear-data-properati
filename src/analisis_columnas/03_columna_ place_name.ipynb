# %% [markdown]
# Análisis de la Columna 1: "operations"

# %%
# Lo primero que hacemos es importar todas las librerias necesarias.
import pandas as pd

# %%
# Abrimos el dataset y hacemos un chequeo rápido para saber cantidad de registros y miramos la composición del mismo.
filename = "../../dataset/properati.csv"
data = pd.read_csv(filename)

display(data.sample(n=6))
# Out:
#        Unnamed: 0 operation property_type     place_name  \
# 21959       21959      sell         house        Rafaela
# 11109       11109      sell         house          Pilar
# 18352       18352      sell     apartment  Mar del Plata
# 25966       25966      sell     apartment        Canning
# 39774       39774      sell     apartment        Palermo
# 27103       27103      sell     apartment        Liniers
#
#                                  place_with_parent_names country_name  \
# 21959                       |Argentina|Santa Fe|Rafaela|    Argentina
# 11109         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 18352  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 25966  |Argentina|Bs.As. G.B.A. Zona Sur|Ezeiza|Canning|    Argentina
# 39774                |Argentina|Capital Federal|Palermo|    Argentina
# 27103                |Argentina|Capital Federal|Liniers|    Argentina
#
#                          state_name  geonames_id                  lat-lon  \
# 21959                      Santa Fe    3839479.0  -31.2569262,-61.4885002
# 11109      Bs.As. G.B.A. Zona Norte    3429979.0    -34.437496,-58.859081
# 18352  Buenos Aires Costa Atlántica    3430863.0  -38.0262127,-57.5361691
# 25966        Bs.As. G.B.A. Zona Sur    3435719.0  -34.8461346,-58.5060854
# 39774               Capital Federal    3430234.0   -34.577365,-58.4131496
# 27103               Capital Federal    3431333.0  -34.6407709,-58.5186039
#
#              lat  ...  surface_covered_in_m2  price_usd_per_m2 price_per_m2  \
# 21959 -31.256926  ...                    NaN               NaN          NaN
# 11109 -34.437496  ...                  123.0               NaN  1300.813008
# 18352 -38.026213  ...                  117.0        880.000000  1880.341880
# 25966 -34.846135  ...                   56.0       1696.428571  1696.428571
# 39774 -34.577365  ...                   30.0       3375.000000  4500.000000
# 27103 -34.640771  ...                   50.0               NaN  3000.000000
#
#        floor  rooms  expenses  \
# 21959    NaN    NaN       NaN
# 11109   10.0    4.0       NaN
# 18352    NaN    4.0       NaN
# 25966    NaN    2.0       NaN
# 39774    NaN    1.0    1000.0
# 27103    NaN    NaN       NaN
#
#                                            properati_url  \
# 21959  http://www.properati.com.ar/17h4n_venta_casa_r...
# 11109  http://www.properati.com.ar/16agz_venta_casa_p...
# 18352  http://www.properati.com.ar/175x7_venta_depart...
# 25966  http://www.properati.com.ar/17qlo_venta_depart...
# 39774  http://www.properati.com.ar/18pbl_venta_depart...
# 27103  http://www.properati.com.ar/17s2r_venta_depart...
#
#                                              description  \
# 21959  IMPORTANTE INMUEBLE A 4 CUADRAS DEL MICROCENTR...
# 11109  Corredor Responsable: Lucrecia Saulle - CSI 55...
# 18352  Amplio departamento 4 ambientes en Playa Grand...
# 25966  Departamento de 2 ambientesExcelente departame...
# 39774  Venta de Departamento monoambiente  en Palermo...
# 27103  CODIGO: 0 ubicado en: Murguiondo 132 -  Public...
#
#                                                    title  \
# 21959                                   San Lorenzo  400
# 11109                      Venta Barrio La Masia Triplex
# 18352  Departamento de 4 ambientes con terraza propia...
# 25966                         DEPARTAMENTOS EN LAS CAVAS
# 39774                              DEPARTAMENTO EN VENTA
# 27103                            Departamento a estrenar
#
#                                          image_thumbnail
# 21959  https://thumbs4.properati.com/8/UmwDl9_8r5lnSR...
# 11109  https://thumbs4.properati.com/9/pML5HD1P4C1pnV...
# 18352  https://thumbs4.properati.com/2/kqDsR7KpYwqpYt...
# 25966  https://thumbs4.properati.com/4/yEqYWPX9j7sYRx...
# 39774  https://thumbs4.properati.com/8/OwyaAbVKvJBfiS...
# 27103  https://thumbs4.properati.com/6/M8Q2bUlxcwJ8kH...
#
# [6 rows x 26 columns]

# %% [markdown]
# # Columna `place_name`:
# Revisamos que opciones tiene, cantidad de registros que se repiten, Nulls, etc.

# %%
# Revisamos si existen valores nulos.
print(f'Cantidad de registros con NaN: {data.place_name.isnull().sum()}')
# Out:
# Cantidad de registros con NaN: 23

# %% [markdown]
# Hay 23 registros Nulos. Al ser pocos podemos imprimiros para ver si se pueden completar de alguna forma.

# %%
mask = data.place_name.isnull()
data[mask]
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 6489         6489      sell         house        NaN
# 10201       10201      sell         house        NaN
# 11451       11451      sell         house        NaN
# 14839       14839      sell         house        NaN
# 18622       18622      sell         house        NaN
# 21922       21922      sell         house        NaN
# 23664       23664      sell         house        NaN
# 24722       24722      sell         house        NaN
# 38856       38856      sell         house        NaN
# 45970       45970      sell     apartment        NaN
# 46642       46642      sell         house        NaN
# 53130       53130      sell         house        NaN
# 55306       55306      sell         house        NaN
# 57703       57703      sell         house        NaN
# 57759       57759      sell         house        NaN
# 57764       57764      sell         house        NaN
# 57793       57793      sell         house        NaN
# 58004       58004      sell         house        NaN
# 58037       58037      sell         house        NaN
# 59069       59069      sell         house        NaN
# 62411       62411      sell         house        NaN
# 62413       62413      sell         house        NaN
# 63849       63849      sell         house        NaN
#
#                            place_with_parent_names country_name  \
# 6489   |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 10201  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 11451  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 14839  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 18622  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 21922  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 23664  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 24722  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 38856  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 45970  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 46642  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 53130  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 55306  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 57703  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 57759  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 57764  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 57793  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 58004  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 58037  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 59069  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 62411  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 62413  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
# 63849  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre||    Argentina
#
#                      state_name  geonames_id                        lat-lon  \
# 6489   Bs.As. G.B.A. Zona Norte          NaN    -34.4008968545,-58.63809847
# 10201  Bs.As. G.B.A. Zona Norte          NaN          -34.400704,-58.638067
# 11451  Bs.As. G.B.A. Zona Norte          NaN  -34.4026880384,-58.6262613379
# 14839  Bs.As. G.B.A. Zona Norte          NaN  -34.4007994779,-58.6381735719
# 18622  Bs.As. G.B.A. Zona Norte          NaN  -34.4032781195,-58.6263503945
# 21922  Bs.As. G.B.A. Zona Norte          NaN          -34.399704,-58.638405
# 23664  Bs.As. G.B.A. Zona Norte          NaN  -34.4005161998,-58.6417999185
# 24722  Bs.As. G.B.A. Zona Norte          NaN        -34.4007292,-58.6377783
# 38856  Bs.As. G.B.A. Zona Norte          NaN         -34.425087,-58.5796585
# 45970  Bs.As. G.B.A. Zona Norte          NaN           -34.396074,-58.63738
# 46642  Bs.As. G.B.A. Zona Norte          NaN          -34.400749,-58.638754
# 53130  Bs.As. G.B.A. Zona Norte          NaN          -34.400978,-58.637809
# 55306  Bs.As. G.B.A. Zona Norte          NaN        -34.3996311,-58.6433121
# 57703  Bs.As. G.B.A. Zona Norte          NaN      -34.39033749,-58.63368988
# 57759  Bs.As. G.B.A. Zona Norte          NaN      -34.39596815,-58.63077164
# 57764  Bs.As. G.B.A. Zona Norte          NaN      -34.39635767,-58.62613678
# 57793  Bs.As. G.B.A. Zona Norte          NaN      -34.39628685,-58.62922668
# 58004  Bs.As. G.B.A. Zona Norte          NaN      -34.39104577,-58.63617897
# 58037  Bs.As. G.B.A. Zona Norte          NaN      -34.39315287,-58.63197327
# 59069  Bs.As. G.B.A. Zona Norte          NaN          -34.400849,-58.638179
# 62411  Bs.As. G.B.A. Zona Norte          NaN          -34.396485,-58.635878
# 62413  Bs.As. G.B.A. Zona Norte          NaN          -34.396485,-58.635878
# 63849  Bs.As. G.B.A. Zona Norte          NaN           -34.39452,-58.632501
#
#              lat  ...  surface_covered_in_m2  price_usd_per_m2  price_per_m2  \
# 6489  -34.400897  ...                  240.0       2708.333333   2708.333333
# 10201 -34.400704  ...                  300.0               NaN   1783.333333
# 11451 -34.402688  ...                  270.0        253.456221   2037.037037
# 14839 -34.400799  ...                  200.0       2000.000000   2400.000000
# 18622 -34.403278  ...                  340.0       3814.705882   3814.705882
# 21922 -34.399704  ...                  220.0               NaN   2000.000000
# 23664 -34.400516  ...                  294.0       1632.653061   1632.653061
# 24722 -34.400729  ...                  270.0       1677.215190   1962.962963
# 38856 -34.425087  ...                  550.0               NaN   2454.545455
# 45970 -34.396074  ...                   27.0       1727.272727   3518.518519
# 46642 -34.400749  ...                   20.0               NaN  73500.000000
# 53130 -34.400978  ...                  370.0        630.000000   1702.702703
# 55306 -34.399631  ...                  204.0       1850.393701   2303.921569
# 57703 -34.390337  ...                  230.0       2826.086957   2826.086957
# 57759 -34.395968  ...                  360.0       1611.111111   1611.111111
# 57764 -34.396358  ...                  391.0       2282.352941   2480.818414
# 57793 -34.396287  ...                  250.0       3040.000000   3040.000000
# 58004 -34.391046  ...                  230.0       2067.669173   2391.304348
# 58037 -34.393153  ...                  320.0       1843.750000   1843.750000
# 59069 -34.400849  ...                  248.0               NaN   2580.645161
# 62411 -34.396485  ...                  170.0       2000.000000   2000.000000
# 62413 -34.396485  ...                  200.0       1676.000000   2095.000000
# 63849 -34.394520  ...                  140.0       2857.142857   2857.142857
#
#        floor  rooms  expenses  \
# 6489     NaN    NaN       NaN
# 10201    NaN    5.0       NaN
# 11451    NaN    NaN       NaN
# 14839    NaN    NaN       NaN
# 18622    NaN    NaN       NaN
# 21922    NaN    5.0       NaN
# 23664    NaN    NaN       NaN
# 24722    NaN    NaN       NaN
# 38856    NaN    NaN       NaN
# 45970    NaN    1.0       NaN
# 46642    NaN    6.0       NaN
# 53130    NaN    NaN       NaN
# 55306    NaN    NaN       NaN
# 57703    NaN    NaN       NaN
# 57759    NaN    NaN       NaN
# 57764    NaN    NaN       NaN
# 57793    NaN    NaN       NaN
# 58004    NaN    NaN       NaN
# 58037    NaN    NaN       NaN
# 59069    NaN    5.0       NaN
# 62411    NaN    4.0       NaN
# 62413    NaN    5.0       NaN
# 63849    NaN    5.0       NaN
#
#                                            properati_url  \
# 6489   http://www.properati.com.ar/15ui7_venta_casa_t...
# 10201  http://www.properati.com.ar/166p5_venta_casa_t...
# 11451  http://www.properati.com.ar/16bpd_venta_casa_t...
# 14839  http://www.properati.com.ar/16tal_venta_casa_b...
# 18622  http://www.properati.com.ar/177ee_venta_casa_t...
# 21922  http://www.properati.com.ar/17gy5_venta_casa_s...
# 23664  http://www.properati.com.ar/17mb5_venta_casa_t...
# 24722  http://www.properati.com.ar/17oz1_venta_casa_t...
# 38856  http://www.properati.com.ar/18mcb_venta_casa_t...
# 45970  http://www.properati.com.ar/1958f_venta_depart...
# 46642  http://www.properati.com.ar/196mk_venta_casa_t...
# 53130  http://www.properati.com.ar/19kkw_venta_casa_t...
# 55306  http://www.properati.com.ar/19ouh_venta_casa_t...
# 57703  http://www.properati.com.ar/19ty5_venta_casa_s...
# 57759  http://www.properati.com.ar/19u2a_venta_casa_b...
# 57764  http://www.properati.com.ar/19u2n_venta_casa_s...
# 57793  http://www.properati.com.ar/19u4u_venta_casa_j...
# 58004  http://www.properati.com.ar/19uld_venta_casa_s...
# 58037  http://www.properati.com.ar/19unl_venta_casa_s...
# 59069  http://www.properati.com.ar/19wuj_venta_casa_b...
# 62411  http://www.properati.com.ar/1a71u_venta_casa_b...
# 62413  http://www.properati.com.ar/1a71w_venta_casa_s...
# 63849  http://www.properati.com.ar/1a9l0_venta_casa_s...
#
#                                              description  \
# 6489   Espectacular casa moderna de una planta, con a...
# 10201  Corredor Responsable: SABRINA COCCONI - CSI 62...
# 11451  MUY LINDA CASA EN EXCELENTE UBICACION!! Superf...
# 14839  Muy linda casa de estilo clásico.-Planta baja;...
# 18622   Casa con increible vista al lago con playa de...
# 21922  Corredor Responsable: Matias Castelli - CUCICB...
# 23664  EXCELENTE CASA CLASICA con grandes ventanas y ...
# 24722  EN EXCLUSIVIDAD!!!!!!Lindísima casa, muy lumin...
# 38856  SANTA MARIA DE TIGRE- AL RIO - ESPECTACULAR CA...
# 45970  EDIFICIO ZERENA – EL PALMAR, NORDELTA. Torre 2...
# 46642  Corredor Responsable: Matias Castelli - CUCICB...
# 53130  Excelente casa en Venta en B° Santa Maria de T...
# 55306  Muy linda casa de dos plantas en lote interno ...
# 57703  Espectacular casas moderna con amplio jardín s...
# 57759  Incluye una amarra de U$S 30.000 con elevador ...
# 57764  IMPECABLE ! Sobre la laguna con excelente orie...
# 57793  Súper cálida y agradable. Ubicada en uno de lo...
# 58004  Casa clásica muy cómoda.PLANTA BAJA: Hall de e...
# 58037  Excelente casa ubicada en uno de la a pocos ba...
# 59069  Corredor Responsable: Matias Castelli - CUCICB...
# 62411  Hermosa casa en lote perimetral, Excelente cal...
# 62413  Muy linda casa a estrenar sobre lote perimetra...
# 63849  Casa estilo colonial de una planta sobre lote ...
#
#                                                    title  \
# 6489               Venta de casa en Santa María de Tigre
# 10201  VENTA CASA SANTA MARÍA DE TIGRE COUNTRY BARRIO...
# 11451                     SANTA MARIA DE TIGRE IMPECABLE
# 14839              Venta de casa en Santa María de Tigre
# 18622  Casa con increible vista al lago con playa y m...
# 21922           Venta Casa - Barrio Santa Maria de Tigre
# 23664    CASA EN VENTA EN SANTA MARIA DE TIGRE CON RENTA
# 24722              Venta de casa en Santa María de Tigre
# 38856                       Casa (barrio cerrado), Venta
# 45970  Excelente monoambiente. Barrio El Palmar.  Con...
# 46642                               Venta de Casa al rio
# 53130                                      Casa en Venta
# 55306             Santa María de Tigre. Casa con amarra.
# 57703                           SANTA MARIA DE TIGRE 100
# 57759                           SANTA MARIA DE TIGRE 100
# 57764                           SANTA MARIA DE TIGRE 100
# 57793                           SANTA MARIA DE TIGRE 100
# 58004                           SANTA MARIA DE TIGRE 100
# 58037                           SANTA MARIA DE TIGRE 100
# 59069      CASA EN VENTA AL AGUA EN SANTA MARIA DE TIGRE
# 62411       VENTA CASA A ESTRENAR EN LAS TIPAS NORDELTA
# 62413             Muy linda casa a estrenar en Las Tipas
# 63849                    Oportunidad! Casa en La Alameda
#
#                                          image_thumbnail
# 6489   https://thumbs4.properati.com/7/vQjgbHSz1fKXxy...
# 10201  https://thumbs4.properati.com/1/FABpKIJMaoAO3t...
# 11451  https://thumbs4.properati.com/5/fwH9L71hW2rW7V...
# 14839  https://thumbs4.properati.com/1/3ZbPSffTY38y7v...
# 18622  https://thumbs4.properati.com/0/52JCH1PKYCOMe6...
# 21922  https://thumbs4.properati.com/8/oO7kmFPYNm8DYr...
# 23664  https://thumbs4.properati.com/2/LQCwH6txpFqetn...
# 24722  https://thumbs4.properati.com/0/Nhx4NejZaQACap...
# 38856  https://thumbs4.properati.com/2/Izq8d5o8ti3kJy...
# 45970  https://thumbs4.properati.com/2/5yvU5E9wOAAzBa...
# 46642  https://thumbs4.properati.com/9/ACeODr7N9CYr9T...
# 53130  https://thumbs4.properati.com/0/3G0TgAjQbNN385...
# 55306  https://thumbs4.properati.com/7/6CoXZSzRyyYJBA...
# 57703  https://thumbs4.properati.com/3/3ax5piHfCls0gT...
# 57759  https://thumbs4.properati.com/8/H6gVgcPkk1wcQu...
# 57764  https://thumbs4.properati.com/1/7lkC4GRTKV-2DS...
# 57793  https://thumbs4.properati.com/7/GbromikV5vgSHJ...
# 58004  https://thumbs4.properati.com/7/1XfLGuboQb9HPW...
# 58037  https://thumbs4.properati.com/1/gnnv0Ek1OhlEIc...
# 59069  https://thumbs4.properati.com/0/yQCPCJupzxW52v...
# 62411  https://thumbs4.properati.com/8/6zjSdUPIdlsKSz...
# 62413  https://thumbs4.properati.com/4/lp2Smi4s4ttX4a...
# 63849  https://thumbs4.properati.com/3/0IZAiDfAhxDRhX...
#
# [23 rows x 26 columns]

# %% [markdown]
# Como tenemos todas las geo-localizaciones de los datos faltantes, vamos a utilizar un endpoint de openstreetmap para obtener la ciudad.

# %%
import requests

lat_lon = "-34.4007292,-58.6377783"
url = f"https://nominatim.openstreetmap.org/search.php?q={lat_lon}&polygon_geojson=1&format=json"
response = requests.get(url=url)
location = response.json()
print(f"La respuesta que obtenemos es:\n{location}\n")
display_name = location[0]["display_name"]
print(f"Seleccionamos el atributo que nos interesa, que tiene todo el string del nombre:\n{display_name}")
# Out:
# La respuesta que obtenemos es:
# [{'place_id': 23599090, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2578819267, 'boundingbox': ['-34.4006682', '-34.4005682', '-58.6379417', '-58.6378417'], 'lat': '-34.4006182', 'lon': '-58.6378917', 'display_name': 'Nani Helados, Avenida Agustín M. García, Barrio El Lucero, Rincón de Milberg, Partido de Tigre, Buenos Aires, 1624, Argentina', 'class': 'amenity', 'type': 'ice_cream', 'importance': 0.001, 'geojson': {'type': 'Point', 'coordinates': [-58.6378917, -34.4006182]}}]
#
# Seleccionamos el atributo que nos interesa, que tiene todo el string del nombre:
# Nani Helados, Avenida Agustín M. García, Barrio El Lucero, Rincón de Milberg, Partido de Tigre, Buenos Aires, 1624, Argentina

# %% [markdown]
# Ahora vamos a probar si nos conviene usar regex o python puro

# %%
# Usando Regex
import re
patron = "\, Partido de Tigre"
regex = re.compile(patron, flags = re.IGNORECASE)
r = regex.split(display_name)

patron = "\, "
regex = re.compile(patron, flags = re.IGNORECASE)
regex_name = regex.split(r[0])[-1]
print(f"La ciudad es: {regex_name}")
# Out:
# La ciudad es: Rincón de Milberg

# %%
# Usando python
city_list = [x.strip() for x in display_name.split(',')]

import numpy as np
new_name = np.nan
for index, name in enumerate(city_list):
    if name.strip() == "Partido de Tigre":
        new_name = city_list[index-1]
        break
print(f"La ciudad es: {new_name}")
# Out:
# La ciudad es: Rincón de Milberg

# %% [markdown]
# Como es más rápida la ejecución con python puro (sin regex), vamos a utilizar ese código para armar la función.

# %%
def get_city(display_name):
    """ Función para obtener la ciudad en base al string completo de la ubicación.
    Convertimos el string en una lista, separandolo en base a las comas, y si matchea con el Partido de Tigre
    retornamos la posición anterior de la lista.
    """
    city_list = [x.strip() for x in display_name.split(',')]
    new_name = np.nan

    for index, name in enumerate(city_list):
        if name.strip() == "Partido de Tigre":
            new_name = city_list[index-1]
            break

    return new_name

# %%
def get_location_from_geo(lat_lon):
    """Funcion que llama al endpoint de openstreetmap para obtener información en base a la latitud y longitud."""
    url = f"https://nominatim.openstreetmap.org/search.php?q={lat_lon}&polygon_geojson=1&format=json"
    response = requests.get(url=url)
    location = response.json()
    return get_city(location[0]["display_name"])

# %%
def complete_city_parent_names(place, city):
    """Función para completar place_with_parent_names con la ciudad."""
    return place[:-1] + city  + place[-1]

# %% [markdown]
# Ahora que tenemos las funciones para obtener la ciudad, vamos a buscar las mismas para cada registro del dataset en donde el campo no este.

# %%
mask = data.place_name.isnull()
locations = data[mask]["lat-lon"].apply(get_location_from_geo)
print(locations)
# Out:
# 6489     Rincón de Milberg
# 10201    Rincón de Milberg
# 11451    Rincón de Milberg
# 14839    Rincón de Milberg
# 18622    Rincón de Milberg
# 21922    Rincón de Milberg
# 23664    Rincón de Milberg
# 24722    Rincón de Milberg
# 38856                Tigre
# 45970    Rincón de Milberg
# 46642    Rincón de Milberg
# 53130    Rincón de Milberg
# 55306    Rincón de Milberg
# 57703    Rincón de Milberg
# 57759    Rincón de Milberg
# 57764    Rincón de Milberg
# 57793    Rincón de Milberg
# 58004    Rincón de Milberg
# 58037    Rincón de Milberg
# 59069    Rincón de Milberg
# 62411    Rincón de Milberg
# 62413    Rincón de Milberg
# 63849    Rincón de Milberg
# Name: lat-lon, dtype: object

# %% [markdown]
# Ahora Guardamos esta nueva información en el dataset.

# %%
data.loc[mask, "place_name"] = locations

# %% [markdown]
# Revisamos de nuevo para ver si quedaron datos con NaN en todo el dataset.

# %%
places = data[mask].apply(lambda x: complete_city_parent_names(x['place_with_parent_names'], x['place_name']), axis=1)
places
# Out:
# 6489     |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 10201    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 11451    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 14839    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 18622    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 21922    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 23664    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 24722    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 38856     |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Tigre|
# 45970    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 46642    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 53130    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 55306    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57703    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57759    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57764    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57793    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 58004    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 58037    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 59069    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 62411    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 62413    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 63849    |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# dtype: object

# %%
data.loc[mask, "place_with_parent_names"] = places

# %%
print(data[mask][["place_name", "place_with_parent_names" ]])
# Out:
#               place_name                            place_with_parent_names
# 6489   Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 10201  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 11451  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 14839  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 18622  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 21922  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 23664  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 24722  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 38856              Tigre   |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Tigre|
# 45970  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 46642  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 53130  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 55306  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57703  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57759  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57764  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 57793  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 58004  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 58037  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 59069  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 62411  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 62413  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...
# 63849  Rincón de Milberg  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Rinc...

# %%
new_mask = data.place_name.isnull()
print(data[new_mask])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, operation, property_type, place_name, place_with_parent_names, country_name, state_name, geonames_id, lat-lon, lat, lon, price, currency, price_aprox_local_currency, price_aprox_usd, surface_total_in_m2, surface_covered_in_m2, price_usd_per_m2, price_per_m2, floor, rooms, expenses, properati_url, description, title, image_thumbnail]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Ahora que no tenemos valores nulos agrupamos por `place_name` y ordenados de forma descendiente.

# %%
# Revisamos los datos que tenemos, agrupados por `place_name` y ordenados de forma descendiente.
print("Contamos cantidad de registros unicos:")
print(data.groupby(['place_name']).size().reset_index(name='count').sort_values(['count'], ascending=False))
# Out:
# Contamos cantidad de registros unicos:
#          place_name  count
# 315         Córdoba   9254
# 798         Rosario   8504
# 612   Mar del Plata   6534
# 925           Tigre   3324
# 668        Nordelta   3315
# ...             ...    ...
# 393          Franck      1
# 820     San Antonio      1
# 397          Gaiman      1
# 399        Garuhapé      1
# 1059        Álvarez      1
#
# [1060 rows x 2 columns]

# %%
# Revisamos los datos que tenemos, agrupados por `place_name` y ordenados de forma descendiente.
print("Contamos cantidad de registros unicos:")
data_agrupada = data.groupby(['place_name']).size().reset_index(name='count').query('count > 1')
print(data_agrupada)
# Out:
# Contamos cantidad de registros unicos:
#                    place_name  count
# 0      Country Maschwitz Club      3
# 2                  9 de Abril      3
# 3                      Abasto    139
# 4         Abril Club de Campo     19
# 5             Acacias Blancas     34
# ...                       ...    ...
# 1050                 Virreyes     41
# 1053                    Wilde    139
# 1055              Yerba Buena    191
# 1056                   Zelaya      7
# 1057                   Zárate     15
#
# [834 rows x 2 columns]
