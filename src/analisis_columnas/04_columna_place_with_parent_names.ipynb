# %% [markdown]
# Análisis de la Columna 1: "place_with_parent_names"

# %%
# Lo primero que hacemos es importar todas las librerias necesarias.
import pandas as pd

# %%
# Abrimos el dataset y hacemos un chequeo rápido para saber cantidad de registros y miramos la composición del mismo.
filename = "../../dataset/properati.csv"
data = pd.read_csv(filename)

display(data.sample(n=6))
# Out:
#         Unnamed: 0 operation property_type          place_name  \
# 62091        62091      sell     apartment             Rosario
# 119785      119785      sell     apartment            Belgrano
# 40379        40379      sell     apartment            Recoleta
# 92741        92741      sell            PH           San Justo
# 40207        40207      sell     apartment       San Cristobal
# 68627        68627      sell         house  Esteban Echeverría
#
#                                   place_with_parent_names country_name  \
# 62091                        |Argentina|Santa Fe|Rosario|    Argentina
# 119785               |Argentina|Capital Federal|Belgrano|    Argentina
# 40379                |Argentina|Capital Federal|Recoleta|    Argentina
# 92741   |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...    Argentina
# 40207           |Argentina|Capital Federal|San Cristobal|    Argentina
# 68627   |Argentina|Bs.As. G.B.A. Zona Sur|Esteban Eche...    Argentina
#
#                       state_name  geonames_id                       lat-lon  \
# 62091                   Santa Fe    3838574.0       -32.9432935,-60.6556847
# 119785           Capital Federal    3436077.0         -34.554184,-58.436424
# 40379            Capital Federal    3429595.0  -34.5972736327,-58.401959354
# 92741   Bs.As. G.B.A. Zona Oeste    3428775.0                           NaN
# 40207            Capital Federal    3429153.0       -34.6244262,-58.3973636
# 68627     Bs.As. G.B.A. Zona Sur    3434003.0                           NaN
#
#               lat  ...  surface_covered_in_m2  price_usd_per_m2 price_per_m2  \
# 62091  -32.943294  ...                  111.0               NaN          NaN
# 119785 -34.554184  ...                   40.0               NaN  4250.000000
# 40379  -34.597274  ...                   45.0       2355.555556  2355.555556
# 92741         NaN  ...                    NaN               NaN          NaN
# 40207  -34.624426  ...                   75.0       2256.410256  2346.666667
# 68627         NaN  ...                  230.0       1695.652174  1695.652174
#
#         floor  rooms  expenses  \
# 62091     NaN    3.0       NaN
# 119785    5.0    1.0       NaN
# 40379     NaN    2.0       NaN
# 92741     NaN    NaN       NaN
# 40207     NaN    4.0       NaN
# 68627     NaN    NaN    6100.0
#
#                                             properati_url  \
# 62091   http://www.properati.com.ar/1a6ni_venta_depart...
# 119785  http://www.properati.com.ar/1ch34_venta_depart...
# 40379   http://www.properati.com.ar/18r7p_venta_depart...
# 92741   http://www.properati.com.ar/1bd87_venta_ph_san...
# 40207   http://www.properati.com.ar/18qv1_venta_depart...
# 68627   http://www.properati.com.ar/1ah4j_venta_casa_e...
#
#                                               description  \
# 62091   Departamento en venta de dos dormitorios. Semi...
# 119785  Corredor Responsable: OSCAR N. LIBERMAN - CUCI...
# 40379   Luminoso semipiso de dos ambientes, en muy bue...
# 92741   PH A LA VENTA EN SAN JUSTO - EXCELENTE UBICACI...
# 40207   Excelente 4 ambientes en venta , a estrenar , ...
# 68627   SAINT THOMAS NORTE - Hermoso Country/Barrio Ce...
#
#                                                     title  \
# 62091   DEPARTAMENTO PRONTA ENTREGA DE DOS DORMITORIOS...
# 119785    Imperdible Monoambiente en La Pampa y Castañeda
# 40379   Luminoso 2 Amb c/Cocina y Baño Reciclados, Exc...
# 92741                  Casa Tipo PH en venta en San Justo
# 40207   Departamento 78 MTS 4 AMBIENTES A UNA CUADRA D...
# 68627                   HERMOSO CHALET EN ST THOMAS NORTE
#
#                                           image_thumbnail
# 62091   https://thumbs4.properati.com/0/ncYwPhyt9vUMbu...
# 119785  https://thumbs4.properati.com/4/siiS87KRd-EOjk...
# 40379   https://thumbs4.properati.com/6/bffw70tdWHI5xx...
# 92741   https://thumbs4.properati.com/2/p2ELungyfR-LHa...
# 40207   https://thumbs4.properati.com/4/hEIlF1bAIc_tFA...
# 68627   https://thumbs4.properati.com/4/N0-_TES2GU0cvV...
#
# [6 rows x 26 columns]

# %% [markdown]
# # Columna `place_with_parent_names`:
#
# En esta columna vamos revisar que no existan valores nulos, y probar si hay consistencia entre los datos que tiene y las columnas `place_name`, `country_name` y `state_name`

# %%
# Revisamos si existen valores nulos.
print(f'Cantidad de registros con NaN: {data.place_with_parent_names.isnull().sum()}')
# Out:
# Cantidad de registros con NaN: 0

# %%
data['place_name'] = data['place_name'].str.strip()

def compare_places(place_with_parent_names, name):
    city = [x.strip() for x in place_with_parent_names.split("|")]
    if name not in city:
        print(name, city)
    return True if name in city else False

mask_places_name = data.apply(lambda x: compare_places(x['place_with_parent_names'], x['place_name']), axis=1)
print(f"La con place_name tiene False: Respuesta: {False in mask_places_name.values}")

mask_places_name = data.apply(lambda x: compare_places(x['place_with_parent_names'], x['country_name']), axis=1)
print(f"La con country_name tiene False: Respuesta: {False in mask_places_name.values}")

mask_places_name = data.apply(lambda x: compare_places(x['place_with_parent_names'], x['state_name']), axis=1)
print(f"La con state_name tiene False: Respuesta: {False in mask_places_name.values}")
# Out:
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# nan ['', 'Argentina', 'Bs.As. G.B.A. Zona Norte', 'Tigre', '', '']
# La con place_name tiene False: Respuesta: True
# La con country_name tiene False: Respuesta: False
# La con state_name tiene False: Respuesta: False
