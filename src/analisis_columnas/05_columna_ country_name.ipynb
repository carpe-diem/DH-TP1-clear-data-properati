# %% [markdown]
# Análisis de la Columna 1: "country_name"

# %%
# Lo primero que hacemos es importar todas las librerias necesarias.
import pandas as pd

# %%
# Abrimos el dataset y hacemos un chequeo rápido para saber cantidad de registros y miramos la composición del mismo.
filename = "../../dataset/properati.csv"
data = pd.read_csv(filename)

display(data.sample(n=6))
# Out:
#         Unnamed: 0 operation property_type         place_name  \
# 41276        41276      sell         house  Carlos Spegazzini
# 48326        48326      sell     apartment            Almagro
# 97068        97068      sell     apartment           Floresta
# 115299      115299      sell     apartment   Villa Carlos Paz
# 42455        42455      sell     apartment              Nuñez
# 120351      120351      sell     apartment          San Telmo
#
#                                   place_with_parent_names country_name  \
# 41276   |Argentina|Bs.As. G.B.A. Zona Sur|Ezeiza|Carlo...    Argentina
# 48326                 |Argentina|Capital Federal|Almagro|    Argentina
# 97068                |Argentina|Capital Federal|Floresta|    Argentina
# 115299               |Argentina|Córdoba|Villa Carlos Paz|    Argentina
# 42455                   |Argentina|Capital Federal|Nuñez|    Argentina
# 120351              |Argentina|Capital Federal|San Telmo|    Argentina
#
#                     state_name  geonames_id                       lat-lon  \
# 41276   Bs.As. G.B.A. Zona Sur          NaN         -34.904481,-58.595753
# 48326          Capital Federal    3436397.0       -34.6110583,-58.4201892
# 97068          Capital Federal    3433910.0  -34.629352033,-58.5048034193
# 115299                 Córdoba    3832791.0                           NaN
# 42455          Capital Federal    3430348.0       -34.5450653,-58.4601599
# 120351         Capital Federal    3428113.0                           NaN
#
#               lat  ...  surface_covered_in_m2  price_usd_per_m2  price_per_m2  \
# 41276  -34.904481  ...                   55.0               NaN    727.272727
# 48326  -34.611058  ...                   93.0       1892.473118   1892.473118
# 97068  -34.629352  ...                   43.0               NaN           NaN
# 115299        NaN  ...                    NaN               NaN           NaN
# 42455  -34.545065  ...                   70.0       3200.000000   3428.571429
# 120351        NaN  ...                   31.0       1897.772647  37112.903226
#
#         floor  rooms  expenses  \
# 41276     NaN    3.0       NaN
# 48326     NaN    4.0       NaN
# 97068     NaN    NaN       NaN
# 115299    NaN    5.0       NaN
# 42455     NaN    3.0       NaN
# 120351    NaN    NaN       NaN
#
#                                             properati_url  \
# 41276   http://www.properati.com.ar/18tvo_venta_casa_c...
# 48326   http://www.properati.com.ar/199xn_venta_depart...
# 97068   http://www.properati.com.ar/1bjjb_venta_depart...
# 115299  http://www.properati.com.ar/1cb1b_venta_depart...
# 42455   http://www.properati.com.ar/18whw_venta_depart...
# 120351  http://www.properati.com.ar/1chub_venta_depart...
#
#                                               description  \
# 41276   Corredor Responsable: Martin Manias - CMCLZ 40...
# 48326   DEPARTAMENTO DE 4 AMBIENTES CON DEPENDENCIA, A...
# 97068   Departamento de 2 ambientes con vista a Av. Lo...
# 115299  Duplex en venta, En Villa Carlos Paz. Córdoba....
# 42455   Hermoso Semipiso al Frente con vista abierta a...
# 120351  Departamento 34m², Capital Federal, San Telmo,...
#
#                                                     title  \
# 41276                         Casa en venta en Spegazzini
# 48326   DEPTO 4 AMB C/DEP. VISTA ABIERTA | AV. RIVADAV...
# 97068                         Departamento - Monte Castro
# 115299  URGENTE.. dpto en Venta a 2 dormitorios y coch...
# 42455   Crisologo Larralde 1500 Hermoso departamento c...
# 120351                           Departamento - San Telmo
#
#                                           image_thumbnail
# 41276   https://thumbs4.properati.com/3/wN28GqX0zqF4P5...
# 48326   https://thumbs4.properati.com/0/-iPzAsLWRKA279...
# 97068   https://thumbs4.properati.com/8/iG-sOXJYovCpK5...
# 115299  https://thumbs4.properati.com/8/MO4kd6SjcGqjo9...
# 42455   https://thumbs4.properati.com/7/p7wxaXAGBVCj1p...
# 120351                                                NaN
#
# [6 rows x 26 columns]

# %% [markdown]
# Revisamos que opciones tiene, o si se repite lo mismo.

# %%
print(f'Cantidad de registros con NaN: {data.country_name.isnull().sum()}')
print("Contamos cantidad de registros unicos:")
print(data.groupby(['country_name']).size().reset_index(name='count'))
# Out:
# Cantidad de registros con NaN: 0
# Contamos cantidad de registros unicos:
#   country_name   count
# 0    Argentina  121220

# %% [markdown]
# ### Detalle de análisis de columna `country_name`:
#
# Vemos que no tiene NaNs y solo tiene la opción `Argentina`. Por este motivo la vamos a eliminar.

# %%
# Borrado de columna operation. Utilizamos inplace=True para que no imprima el resultado.
data.drop(['country_name'], axis=1, inplace=True)

# %%
display(data.sample(n=6))
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 78779       78779      sell     apartment   La Plata
# 68083       68083      sell         house   Banfield
# 62115       62115      sell     apartment   Floresta
# 4887         4887      sell            PH      Boedo
# 87003       87003      sell     apartment    Rosario
# 453           453      sell         house    Rosario
#
#                                  place_with_parent_names  \
# 78779        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|
# 68083  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...
# 62115               |Argentina|Capital Federal|Floresta|
# 4887                   |Argentina|Capital Federal|Boedo|
# 87003                       |Argentina|Santa Fe|Rosario|
# 453                         |Argentina|Santa Fe|Rosario|
#
#                    state_name  geonames_id                  lat-lon  \
# 78779  Bs.As. G.B.A. Zona Sur    3432039.0                      NaN
# 68083  Bs.As. G.B.A. Zona Sur    3436152.0                      NaN
# 62115         Capital Federal    3433910.0  -34.6282465,-58.4844109
# 4887          Capital Federal    3436003.0  -34.6431859,-58.4239137
# 87003                Santa Fe    3838574.0                      NaN
# 453                  Santa Fe    3838574.0    -32.972331,-60.630479
#
#              lat        lon  ...  surface_covered_in_m2 price_usd_per_m2  \
# 78779        NaN        NaN  ...                   49.0              NaN
# 68083        NaN        NaN  ...                  280.0      2321.428571
# 62115 -34.628247 -58.484411  ...                   32.0              NaN
# 4887  -34.643186 -58.423914  ...                  230.0       960.000000
# 87003        NaN        NaN  ...                   33.0      1557.879722
# 453   -32.972331 -60.630479  ...                  100.0              NaN
#
#        price_per_m2  floor  rooms  expenses  \
# 78779           NaN    NaN    NaN       NaN
# 68083   2321.428571    NaN    NaN       NaN
# 62115           NaN    NaN    1.0       NaN
# 4887    1043.478261    NaN    5.0       NaN
# 87003  30303.030303    NaN    NaN       NaN
# 453    11000.000000    NaN    4.0       NaN
#
#                                            properati_url  \
# 78779  http://www.properati.com.ar/1aumi_venta_depart...
# 68083  http://www.properati.com.ar/1agaz_venta_casa_b...
# 62115  http://www.properati.com.ar/1a6oe_venta_depart...
# 4887   http://www.properati.com.ar/15odn_venta_ph_boe...
# 87003  http://www.properati.com.ar/1b57o_venta_depart...
# 453    http://www.properati.com.ar/15emh_venta_casa_r...
#
#                                              description  \
# 78779  Ubicación estratégica de la ciudad de La Plata...
# 68083  EXCELENTE PROPIEDAD  DESARROLLADA EN TRES NIVE...
# 62115  Excelentes departamentos a estrenar de un ambi...
# 4887   Hermoso Ph al frente  con entrada independient...
# 87003  Amplio monoambiente divisible, posee ambiente ...
# 453    Corredor Responsable: Sebastian Pellegrini - C...
#
#                                                    title  \
# 78779                   Land 48 - 48 entre 14 y 15 - 2°A
# 68083                                    CHALET EN VENTA
# 62115        A ESTRENAR AMBIENTE DIVISIBLE MUY LUMINOSO!
# 4887   PH AL FRENTE CON ENTRADA INDEPENDIENTE ES MUY ...
# 87003                             Departamento - Rosario
# 453               Lote Ideal para Constructora - Rosario
#
#                                          image_thumbnail
# 78779  https://thumbs4.properati.com/4/s18pXnkCkbGD3U...
# 68083  https://thumbs4.properati.com/1/-HtjpA7MKbzwHz...
# 62115  https://thumbs4.properati.com/8/HPiSsqIyG9v5J8...
# 4887   https://thumbs4.properati.com/2/LMMCdETxgwtWal...
# 87003  https://thumbs4.properati.com/0/JmS2dj6OvFH3d9...
# 453    https://thumbs4.properati.com/5/FvBRz4jx1dqzWF...
#
# [6 rows x 25 columns]
