# %% [markdown]
# Análisis de la Columna 1: "operations"

# %%
# Lo primero que hacemos es importar todas las librerias necesarias.
import pandas as pd

# %%
# Abrimos el dataset y hacemos un chequeo rápido para saber cantidad de registros y miramos la composición del mismo.
filename = "../../dataset/properati.csv"
data = pd.read_csv(filename)

display(data.sample(n=6))
# Out:
#        Unnamed: 0 operation property_type           place_name  \
# 44002       44002      sell         house  Barrio Santa Teresa
# 18869       18869      sell            PH         Villa Devoto
# 16743       16743      sell     apartment         Barrio Norte
# 64771       64771      sell         house               Olivos
# 5735         5735      sell     apartment              Rosario
# 42316       42316      sell     apartment         San Fernando
#
#                                  place_with_parent_names country_name  \
# 44002  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Barr...    Argentina
# 18869           |Argentina|Capital Federal|Villa Devoto|    Argentina
# 16743           |Argentina|Capital Federal|Barrio Norte|    Argentina
# 64771  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 5735                        |Argentina|Santa Fe|Rosario|    Argentina
# 42316  |Argentina|Bs.As. G.B.A. Zona Norte|San Fernan...    Argentina
#
#                      state_name  geonames_id                        lat-lon  \
# 44002  Bs.As. G.B.A. Zona Norte          NaN  -34.3933631122,-58.7005081094
# 18869           Capital Federal    3427451.0           -34.587056,-58.51243
# 16743           Capital Federal    3436109.0  -34.5924958714,-58.3786739676
# 64771  Bs.As. G.B.A. Zona Norte    3430310.0                            NaN
# 5735                   Santa Fe    3838574.0        -32.9371824,-60.6418905
# 42316  Bs.As. G.B.A. Zona Norte          NaN        -34.4411262,-58.5550387
#
#              lat  ...  surface_covered_in_m2  price_usd_per_m2  price_per_m2  \
# 44002 -34.393363  ...                  320.0       1900.000000   2078.125000
# 18869 -34.587056  ...                   84.0               NaN   3095.238095
# 16743 -34.592496  ...                  206.0       2766.990291   2766.990291
# 64771        NaN  ...                   90.0               NaN   2333.333333
# 5735  -32.937182  ...                   90.0       1178.047400  46678.166667
# 42316 -34.441126  ...                   60.0       1935.483871   2000.000000
#
#        floor  rooms  expenses  \
# 44002    NaN    NaN       NaN
# 18869    1.0    4.0       NaN
# 16743    NaN    6.0       NaN
# 64771    NaN    NaN       NaN
# 5735     NaN    NaN       NaN
# 42316    NaN    3.0       NaN
#
#                                            properati_url  \
# 44002  http://www.properati.com.ar/18zhq_venta_casa_t...
# 18869  http://www.properati.com.ar/17843_venta_ph_vil...
# 16743  http://www.properati.com.ar/16zeq_venta_depart...
# 64771  http://www.properati.com.ar/1ab8y_venta_casa_o...
# 5735   http://www.properati.com.ar/15rkh_venta_depart...
# 42316  http://www.properati.com.ar/18w63_venta_depart...
#
#                                              description  \
# 44002  Excelente casa en el barrio Santa Teresa. Sobr...
# 18869  Corredor Responsable: Gabriel Sola - CUCICBA 2...
# 16743  Piso de categoría, muy luminoso! Palier privad...
# 64771  Casa de 3 ambientes en esquina, con pequeño pa...
# 5735   CODIGO: 3855-JP-000062 ubicado en: Jujuy 1515 ...
# 42316  3 ambientes a estrenar! Cocina, lavadero, livi...
#
#                                                    title  \
# 44002  VILLANUEVA | SANTA TERESA | Importante Casa en...
# 18869  Venta Duplex 4 Amb c/patio y terraza -Villa De...
# 16743                                  Suipacha y Arroyo
# 64771                                     PH 3 ambientes
# 5735   Departamento 3 dormitorios en venta en Rosario...
# 42316    Excelente Departamento en venta en San Fernando
#
#                                          image_thumbnail
# 44002  https://thumbs4.properati.com/0/UfajTmJKnYKAz4...
# 18869  https://thumbs4.properati.com/5/fopCCO1JbdIcXz...
# 16743  https://thumbs4.properati.com/9/8e4ur1rkyCGQHd...
# 64771  https://thumbs4.properati.com/5/fR8Wsu3AmSrKl0...
# 5735   https://thumbs4.properati.com/7/fcE4v2ELFCL5vu...
# 42316  https://thumbs4.properati.com/0/QvZJsivV30UlPN...
#
# [6 rows x 26 columns]

# %% [markdown]
# Revisamos que opciones tiene, o si se repite lo mismo.

# %%
print(f'Cantidad de registros con NaN: {data.operation.isnull().sum()}')
print("Contamos cantidad de registros unicos:")
print(data.groupby(['operation']).size().reset_index(name='count'))
# Out:
# Cantidad de registros con NaN: 0
# Contamos cantidad de registros unicos:
#   operation   count
# 0      sell  121220

# %% [markdown]
# Detalle de análisis de columnas:
# * `operation` -> Vemos que no tiene NaNs y solo tiene la opción `sell`. Por este motivo la vamos a eliminar.

# %%
# Borrado de columna operation. Utilizamos inplace=True para que no imprima el resultado.
data.drop(['operation'], axis=1, inplace=True)

# %%
display(data.sample(n=6))
# Out:
#         Unnamed: 0 property_type     place_name  \
# 31587        31587     apartment     San Miguel
# 43780        43780         house        Córdoba
# 42084        42084     apartment     Colegiales
# 98129        98129     apartment  Villa Urquiza
# 81781        81781     apartment      Caballito
# 106341      106341         house  Villa Primera
#
#                                   place_with_parent_names country_name  \
# 31587   |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 43780                         |Argentina|Córdoba|Córdoba|    Argentina
# 42084              |Argentina|Capital Federal|Colegiales|    Argentina
# 98129           |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 81781               |Argentina|Capital Federal|Caballito|    Argentina
# 106341  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                           state_name  geonames_id  \
# 31587       Bs.As. G.B.A. Zona Norte          NaN
# 43780                        Córdoba    3860259.0
# 42084                Capital Federal    3435356.0
# 98129                Capital Federal    3433775.0
# 81781                Capital Federal    3435874.0
# 106341  Buenos Aires Costa Atlántica          NaN
#
#                               lat-lon        lat        lon  ...  \
# 31587          -34.5436617,-58.705704 -34.543662 -58.705704  ...
# 43780         -31.4537529,-64.1098456 -31.453753 -64.109846  ...
# 42084          -34.573137,-58.4393395 -34.573137 -58.439340  ...
# 98129   -34.5728577902,-58.4816077246 -34.572858 -58.481608  ...
# 81781    -34.6270289936,-58.444241187 -34.627029 -58.444241  ...
# 106341                            NaN        NaN        NaN  ...
#
#         surface_covered_in_m2 price_usd_per_m2  price_per_m2  floor  rooms  \
# 31587                     NaN              NaN           NaN    4.0    NaN
# 43780                    95.0              NaN   7368.421053    1.0    2.0
# 42084                    55.0      2363.636364   2363.636364    NaN    3.0
# 98129                    45.0      2468.354430   4333.333333    NaN    NaN
# 81781                   158.0      2197.802198   2531.645570    NaN    NaN
# 106341                  229.0       938.864629    938.864629    NaN    NaN
#
#         expenses                                      properati_url  \
# 31587        NaN  http://www.properati.com.ar/184ql_venta_depart...
# 43780        NaN  http://www.properati.com.ar/18z41_venta_casa_c...
# 42084        NaN  http://www.properati.com.ar/18vpp_venta_depart...
# 98129        NaN  http://www.properati.com.ar/1bl4e_venta_depart...
# 81781     9102.0  http://www.properati.com.ar/1ayf7_venta_depart...
# 106341       NaN  http://www.properati.com.ar/1bw7a_venta_casa_v...
#
#                                               description  \
# 31587   DEPARTAMENTO APTO PROFESIONAL A LA VENTA EN SA...
# 43780                 Casa en Venta de 1 dorm. en Cordoba
# 42084   Hermoso departamento de 3 ambientes, muy lumin...
# 98129   Excelente 2 ambientes en inmejorable ubicación...
# 81781   * Piso de 5 ambientes con Dependencia de servi...
# 106341  Chalet de categoría integramente reciclado a n...
#
#                                                     title  \
# 31587                               DEPARTAMENTO EN VENTA
# 43780                             CASA BARRIO SAN LORENZO
# 42084         DEPARTAMENTO 3 AMBIENTES, VENTA. COLEGIALES
# 98129                        Departamento - Villa Urquiza
# 81781   Av. Pedro Goyena 1221 1° - Piso de 5 Ambientes...
# 106341  CHALET DE CATEGORIA EN VILLA PRIMERA PARQUE LU...
#
#                                           image_thumbnail
# 31587   https://thumbs4.properati.com/9/s7A5Ar03LZh9kH...
# 43780   https://thumbs4.properati.com/7/zZawKyqnAdxmsU...
# 42084   https://thumbs4.properati.com/9/uwabxc_gEZ8tAV...
# 98129   https://thumbs4.properati.com/0/BjCnNmluc5SiTu...
# 81781   https://thumbs4.properati.com/6/Hr4CUdDWK__rJ7...
# 106341  https://thumbs4.properati.com/2/hRDFbeeaQHgTFE...
#
# [6 rows x 25 columns]
