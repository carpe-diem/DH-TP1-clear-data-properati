# %% [markdown]
# Análisis de la Columna 1: "property_type"

# %%
# Lo primero que hacemos es importar todas las librerias necesarias.
import pandas as pd

# %%
# Abrimos el dataset y hacemos un chequeo rápido para saber cantidad de registros y miramos la composición del mismo.
filename = "../../dataset/properati.csv"
data = pd.read_csv(filename)

display(data.sample(n=6))
# Out:
#        Unnamed: 0 operation property_type     place_name  \
# 91105       91105      sell     apartment        Córdoba
# 42441       42441      sell     apartment      Balvanera
# 86189       86189      sell     apartment  Puerto Madero
# 33191       33191      sell         house  Mar del Plata
# 85525       85525      sell     apartment   Villa Crespo
# 16869       16869      sell     apartment  Monte Hermoso
#
#                                  place_with_parent_names country_name  \
# 91105                                |Argentina|Córdoba|    Argentina
# 42441              |Argentina|Capital Federal|Balvanera|    Argentina
# 86189          |Argentina|Capital Federal|Puerto Madero|    Argentina
# 33191  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 85525           |Argentina|Capital Federal|Villa Crespo|    Argentina
# 16869  |Argentina|Buenos Aires Costa Atlántica|Monte ...    Argentina
#
#                          state_name  geonames_id  \
# 91105                       Córdoba    3860255.0
# 42441               Capital Federal    6693228.0
# 86189               Capital Federal    3429760.0
# 33191  Buenos Aires Costa Atlántica    3430863.0
# 85525               Capital Federal    3427458.0
# 16869  Buenos Aires Costa Atlántica    3843843.0
#
#                              lat-lon        lat  ...  surface_covered_in_m2  \
# 91105                            NaN        NaN  ...                   90.0
# 42441        -34.6088196,-58.3962607 -34.608820  ...                   94.0
# 86189  -34.6094375423,-58.3628508831 -34.609438  ...                  214.0
# 33191        -38.1105093,-57.6208853 -38.110509  ...                  230.0
# 85525  -34.5964389603,-58.4401969549 -34.596439  ...                    NaN
# 16869   -38.9887171125,-61.281084411 -38.988717  ...                    NaN
#
#        price_usd_per_m2 price_per_m2  floor  rooms  expenses  \
# 91105               NaN  2222.222222    NaN    NaN       NaN
# 42441       1616.161616  1702.127660    NaN    3.0       NaN
# 86189       7476.635514  7476.635514    NaN    NaN       1.0
# 33191       1434.782609  1434.782609    NaN    5.0       NaN
# 85525               NaN          NaN    NaN    NaN       NaN
# 16869       2588.235294          NaN    NaN    3.0       NaN
#
#                                            properati_url  \
# 91105  http://www.properati.com.ar/1bb49_venta_depart...
# 42441  http://www.properati.com.ar/18wgw_venta_depart...
# 86189  http://www.properati.com.ar/1b41y_venta_depart...
# 33191  http://www.properati.com.ar/188qg_venta_casa_m...
# 85525  http://www.properati.com.ar/1b355_venta_depart...
# 16869  http://www.properati.com.ar/16zp8_venta_depart...
#
#                                              description  \
# 91105  HDH PROPIEDADES PRESENTA A LA VENTA DEPARTAMEN...
# 42441  MUY BUEN DEPARTAMENTO DE 3 AMBIENTES CON DEPEN...
# 86189  RENOIR II Excelente Dto. 4 Amb. Dep. Piso alto...
# 33191  RUMENCO – BARRIO LOS PINOSSup. Cub. 230 mts2 C...
# 85525  7 Departamentos monoambientes divisibles con b...
# 16869  VISTA DIRECTA AL MAR DESDE UN BELLO BALCÓN CON...
#
#                                                    title  \
# 91105                       Departamento - Nueva Cordoba
# 42441   3 AMBIENTES CON DEPENDENCIA Y 2 BALCONES AL F...
# 86189          RENOIR II SOL piso alto. con dos cocheras
# 33191                                     CASA EN VENTA
# 85525                        Departamento - Villa Crespo
# 16869            A ESTRENAR! 2 DORMITORIOS FRENTE AL MAR
#
#                                          image_thumbnail
# 91105  https://thumbs4.properati.com/5/77Est1i_7Hzljt...
# 42441  https://thumbs4.properati.com/0/7E-sW1CrhODuwl...
# 86189  https://thumbs4.properati.com/3/be6Bh8zDBz2Tj_...
# 33191  https://thumbs4.properati.com/0/BQ7WgwOFzzX4gx...
# 85525  https://thumbs4.properati.com/4/t8lKQMYwuJeSo7...
# 16869  https://thumbs4.properati.com/3/bHzFMxPDRnXNOj...
#
# [6 rows x 26 columns]

# %% [markdown]
# Revisamos que opciones tiene, o si se repite lo mismo.

# %%
print(f'Cantidad de registros con NaN: {data.property_type.isnull().sum()}')
print("Contamos cantidad de registros unicos:")
print(data.groupby(['property_type']).size().reset_index(name='count'))
# Out:
# Cantidad de registros con NaN: 0
# Contamos cantidad de registros unicos:
#   property_type  count
# 0            PH   5751
# 1     apartment  71065
# 2         house  40268
# 3         store   4136

# %% [markdown]
# ### Detalle de análisis de columna `proporty_type`:
#
# Vemos que no tiene NaNs y tiene 4 categorias `PH`, `apartment`, `house` y `store`.
#
# Todas las categorias tienen una cantidad razonable de datos, por lo que vamos a dejarla sin modificar.

# %%
data.groupby('property_type').size().reset_index(name='Cantidad').plot(kind='bar')
# Out:
# <AxesSubplot: >
